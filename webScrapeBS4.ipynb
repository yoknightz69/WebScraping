# %%
# !pip install selenium

import pandas as pd
import json
# Out:
# Requirement already satisfied: selenium in c:\users\zflor\anaconda3\lib\site-packages (4.40.0)
# Requirement already satisfied: certifi>=2026.1.4 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (2026.1.4)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: trio-typing>=0.10.0 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (0.10.0)
# Requirement already satisfied: types-certifi>=2021.10.8.3 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (2021.10.8.3)
# Requirement already satisfied: types-urllib3>=1.26.25.14 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (1.26.25.14)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in c:\users\zflor\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.6.3)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\zflor\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\zflor\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\zflor\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\zflor\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Requirement already satisfied: outcome in c:\users\zflor\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\zflor\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\zflor\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\zflor\anaconda3\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\zflor\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\zflor\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: mypy-extensions>=0.4.2 in c:\users\zflor\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium) (1.0.0)
# Requirement already satisfied: async-generator in c:\users\zflor\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium) (1.10)
# Requirement already satisfied: packaging in c:\users\zflor\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium) (25.0)
# Requirement already satisfied: importlib-metadata in c:\users\zflor\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium) (8.7.0)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\zflor\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\zflor\anaconda3\lib\site-packages (from importlib-metadata->trio-typing>=0.10.0->selenium) (3.23.0)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

URL = "https://builtwith.com/detailed/juniper.net"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

# Extract all links
data = []
for link in soup.find_all("a"):
    data.append({
        "text": link.get_text(strip=True),
        "href": link.get("href")
    })

df = pd.DataFrame(data)

# Display settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 2000)

df
# Out:
#                                            text                                                               href
# 0                                        Log In                                              //builtwith.com/login
# 1                               Signup for Free                                             //builtwith.com/signup
# 2                                            EN                                              /detailed/juniper.net
# 3                                            DE                                           /de/detailed/juniper.net
# 4                                            FR                                           /fr/detailed/juniper.net
# 5                                            ES                                           /es/detailed/juniper.net
# 6                                            IT                                           /it/detailed/juniper.net
# 7                                       Pусский                                           /ru/detailed/juniper.net
# 8                                           한국어                                           /ko/detailed/juniper.net
# 9                                           日本語                                           /ja/detailed/juniper.net
# 10                                         简体中文                                           /zh/detailed/juniper.net
# 11                                         عربي                                           /ar/detailed/juniper.net
# 12                                                                                                 //builtwith.com
# 13                                        Tools                                                 javascript:void(0)
# 14                        Web Technology Trends                                             //trends.builtwith.com
# 15                                Keyword Lists                                      //builtwith.com/website-lists
# 16                      eCommerce Product Lists                                          //builtwith.com/ecommerce
# 17                                    Top Sites                                          //builtwith.com/top-sites
# 18                          Technology Investor                             //trends.builtwith.com/investor-center
# 19                                    LeadsEye™                                          //leadseye.builtwith.com/
# 20                                   API Access                                                //api.builtwith.com
# 21                                     Datasets                                           //builtwith.com/datasets
# 22                           Browser Extensions                                            //builtwith.com/toolbar
# 23                             CRM Integrations                                   //builtwith.com/crm-integrations
# 24                                     Features                                                 javascript:void(0)
# 25                              Lead Generation                                    //builtwith.com/lead-generation
# 26                              Market Analysis                                    //builtwith.com/market-analysis
# 27                           Sales Intelligence                                 //builtwith.com/sales-intelligence
# 28                             Future Customers                                   //builtwith.com/future-customers
# 29                         Global Data Coverage                                      //builtwith.com/data-coverage
# 30                          Cyber Risk Auditing                                         //builtwith.com/cyber-risk
# 31                   Alternative Financial Data                                   //builtwith.com/alternative-data
# 32                               BuiltWith + AI                            //builtwith.com/artificial-intelligence
# 33                             Report Filtering                                   //builtwith.com/report-filtering
# 34                                    Use Cases                                          //builtwith.com/use-cases
# 35                                 All Features                                       //builtwith.com/all-features
# 36                              Screencast Demo                                         //builtwith.com/screencast
# 37                                        Plans                                              //builtwith.com/plans
# 38                                    Customers                                          //builtwith.com/customers
# 39                                    Resources                                                 javascript:void(0)
# 40                              Screencast Demo                                         //builtwith.com/screencast
# 41                               Knowledge Base                                                //kb.builtwith.com/
# 42                            Exportable Fields                                  //builtwith.com/exportable-fields
# 43                                          FAQ                                                //builtwith.com/faq
# 44                                     About Us                                              //builtwith.com/about
# 45                                   Contact Us                                            //builtwith.com/contact
# 46                                   Affiliates                                        //affiliates.builtwith.com/
# 47                                         Blog                                              //blog.builtwith.com/
# 48                                         Home                                                                  /
# 49               juniper.net Technology Profile                                               /juniper.net?NR=true
# 50                           Technology Profile                                                       /juniper.net
# 51                                     Detailed                                              /detailed/juniper.net
# 52                                         Meta                                                  /meta/juniper.net
# 53                                     Products                                              /products/juniper.net
# 54                                  Performance                                           /performance/juniper.net
# 55                                 Relationship                                         /relationships/juniper.net
# 56                                     Redirect                                             /redirects/juniper.net
# 57                              Recommendations                                       /recommendations/juniper.net
# 58                                      Company                                               /company/juniper.net
# 59               Upgrade to Advanced Discounted                            //builtwith.com/checkout/advanced-black
# 60                   Update to Advanced Monthly                          //builtwith.com/checkout/advanced-monthly
# 61                    See a Sample Full Profile                               //builtwith.com/detailed/wayfair.com
# 62                                                                                                            None
# 63                        Omniture SiteCatalyst             //trends.builtwith.com/analytics/Omniture-SiteCatalyst
# 64                         Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 65               Omniture Adobe Test and Target    //trends.builtwith.com/analytics/Omniture-Adobe-Test-and-Target
# 66                                  A/B Testing                       //trends.builtwith.com/analytics/a-b-testing
# 67                         Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 68                      Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 69                         Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 70                              Personalization                   //trends.builtwith.com/analytics/personalization
# 71                      Product Recommendations           //trends.builtwith.com/analytics/product-recommendations
# 72                        Adobe Target Standard             //trends.builtwith.com/analytics/Adobe-Target-Standard
# 73                                  A/B Testing                       //trends.builtwith.com/analytics/a-b-testing
# 74                            Adobe Target v1.x                 //trends.builtwith.com/analytics/Adobe-Target-v1.x
# 75                                       Eloqua                            //trends.builtwith.com/analytics/Eloqua
# 76                         Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 77                                          CRM                               //trends.builtwith.com/analytics/crm
# 78                              Lead Generation                   //trends.builtwith.com/analytics/lead-generation
# 79                              Personalization                   //trends.builtwith.com/analytics/personalization
# 80                        Adobe Marketing Cloud             //trends.builtwith.com/analytics/Adobe-Marketing-Cloud
# 81                         Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 82                         Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 83                                   Salesforce                        //trends.builtwith.com/analytics/Salesforce
# 84                                          CRM                               //trends.builtwith.com/analytics/crm
# 85                                     Highspot                          //trends.builtwith.com/analytics/Highspot
# 86                              Lead Generation                   //trends.builtwith.com/analytics/lead-generation
# 87                                 Adobe Launch                      //trends.builtwith.com/analytics/Adobe-Launch
# 88                               Tag Management                    //trends.builtwith.com/analytics/tag-management
# 89                                Akamai mPulse                     //trends.builtwith.com/analytics/Akamai-mPulse
# 90                      Application Performance           //trends.builtwith.com/analytics/application-performance
# 91                 Adobe Dynamic Tag Management      //trends.builtwith.com/analytics/Adobe-Dynamic-Tag-Management
# 92                               Tag Management                    //trends.builtwith.com/analytics/tag-management
# 93                                  PathFactory                       //trends.builtwith.com/analytics/PathFactory
# 94                         Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 95             Adobe Experience Platform Launch  //trends.builtwith.com/analytics/Adobe-Experience-Platform-Launch
# 96                               Tag Management                    //trends.builtwith.com/analytics/tag-management
# 97                                    Leadspace                         //trends.builtwith.com/analytics/Leadspace
# 98                         Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 99                       Customer Data Platform            //trends.builtwith.com/analytics/customer-data-platform
# 100                                     Rapleaf                           //trends.builtwith.com/analytics/Rapleaf
# 101                        Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 102                                    KickFire                          //trends.builtwith.com/analytics/KickFire
# 103                             Lead Generation                   //trends.builtwith.com/analytics/lead-generation
# 104                      DoubleClick Floodlight            //trends.builtwith.com/analytics/DoubleClick-Floodlight
# 105                            Google Analytics                  //trends.builtwith.com/analytics/Google-Analytics
# 106                     Application Performance           //trends.builtwith.com/analytics/application-performance
# 107                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 108                      Visitor Count Tracking            //trends.builtwith.com/analytics/visitor-count-tracking
# 109                  Google Universal Analytics        //trends.builtwith.com/analytics/Google-Universal-Analytics
# 110                    Google Analytics Classic          //trends.builtwith.com/analytics/Google-Analytics-Classic
# 111                  Google Conversion Tracking        //trends.builtwith.com/analytics/Google-Conversion-Tracking
# 112                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 113                         Conversion Tracking               //trends.builtwith.com/analytics/conversion-tracking
# 114                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 115                         Advertiser Tracking               //trends.builtwith.com/analytics/advertiser-tracking
# 116                         Conversion Tracking               //trends.builtwith.com/analytics/conversion-tracking
# 117                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 118                         Advertiser Tracking               //trends.builtwith.com/analytics/advertiser-tracking
# 119                         Conversion Tracking               //trends.builtwith.com/analytics/conversion-tracking
# 120                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 121                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 122                                      Mobile                            //trends.builtwith.com/analytics/mobile
# 123                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 124                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 125                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 126                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 127                   Retargeting / Remarketing         //trends.builtwith.com/analytics/retargeting---remarketing
# 128                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 129                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 130                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 131                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 132                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 133                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 134                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 135                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 136                         Conversion Tracking               //trends.builtwith.com/analytics/conversion-tracking
# 137                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 138                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 139                     Application Performance           //trends.builtwith.com/analytics/application-performance
# 140                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 141                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 142                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 143                           Site Optimization                 //trends.builtwith.com/analytics/site-optimization
# 144                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 145                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 146                        Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 147                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 148                         Advertiser Tracking               //trends.builtwith.com/analytics/advertiser-tracking
# 149                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 150                        Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 151                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 152                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 153                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 154                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 155                                 A/B Testing                       //trends.builtwith.com/analytics/a-b-testing
# 156                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 157                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 158                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 159                  Feedback Forms and Surveys        //trends.builtwith.com/analytics/feedback-forms-and-surveys
# 160                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 161                           Site Optimization                 //trends.builtwith.com/analytics/site-optimization
# 162                                      Mobile                            //trends.builtwith.com/analytics/mobile
# 163                              Error Tracking                    //trends.builtwith.com/analytics/error-tracking
# 164                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 165                         Conversion Tracking               //trends.builtwith.com/analytics/conversion-tracking
# 166                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 167                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 168                         Advertiser Tracking               //trends.builtwith.com/analytics/advertiser-tracking
# 169                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 170                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 171                             Lead Generation                   //trends.builtwith.com/analytics/lead-generation
# 172                        Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 173                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 174                         Advertiser Tracking               //trends.builtwith.com/analytics/advertiser-tracking
# 175                    Data Management Platform          //trends.builtwith.com/analytics/data-management-platform
# 176                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 177                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 178                     Conversion Optimization           //trends.builtwith.com/analytics/conversion-optimization
# 179                     Product Recommendations           //trends.builtwith.com/analytics/product-recommendations
# 180                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 181                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 182                        Marketing Automation              //trends.builtwith.com/analytics/marketing-automation
# 183                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 184                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 185                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 186                  Feedback Forms and Surveys        //trends.builtwith.com/analytics/feedback-forms-and-surveys
# 187                      Customer Data Platform            //trends.builtwith.com/analytics/customer-data-platform
# 188                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 189                             Personalization                   //trends.builtwith.com/analytics/personalization
# 190                     Product Recommendations           //trends.builtwith.com/analytics/product-recommendations
# 191                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 192                           Site Optimization                 //trends.builtwith.com/analytics/site-optimization
# 193                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 194                        Audience Measurement              //trends.builtwith.com/analytics/audience-measurement
# 195                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 196                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 197                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 198                         Advertiser Tracking               //trends.builtwith.com/analytics/advertiser-tracking
# 199                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 200                                   Live Chat                           //trends.builtwith.com/widgets/live-chat
# 201                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 202                                 Site Search                         //trends.builtwith.com/widgets/site-search
# 203                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 204                          Privacy Compliance                  //trends.builtwith.com/widgets/privacy-compliance
# 205                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 206                          Privacy Compliance                  //trends.builtwith.com/widgets/privacy-compliance
# 207                              Tag Management                      //trends.builtwith.com/widgets/tag-management
# 208                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 209                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 210                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 211                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 212                                      Mobile                              //trends.builtwith.com/widgets/mobile
# 213                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 214                              Tag Management                      //trends.builtwith.com/widgets/tag-management
# 215                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 216                                 Site Search                         //trends.builtwith.com/widgets/site-search
# 217                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 218                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 219                                   Live Chat                           //trends.builtwith.com/widgets/live-chat
# 220                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 221                  Feedback Forms and Surveys          //trends.builtwith.com/widgets/feedback-forms-and-surveys
# 222                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 223                                       Fonts                               //trends.builtwith.com/widgets/fonts
# 224                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 225                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 226                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 227                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 228                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 229                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 230                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 231                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 232                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 233                          Privacy Compliance                  //trends.builtwith.com/widgets/privacy-compliance
# 234                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 235                          Privacy Compliance                  //trends.builtwith.com/widgets/privacy-compliance
# 236                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 237                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 238                                     CAPTCHA                             //trends.builtwith.com/widgets/captcha
# 239                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 240                                     CAPTCHA                             //trends.builtwith.com/widgets/captcha
# 241                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 242                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 243                              Image Provider                      //trends.builtwith.com/widgets/image-provider
# 244                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 245                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 246                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 247                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 248                               Bot Detection                       //trends.builtwith.com/widgets/bot-detection
# 249                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 250                                       Fonts                               //trends.builtwith.com/widgets/fonts
# 251                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 252                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 253                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 254                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 255                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 256                                   Live Chat                           //trends.builtwith.com/widgets/live-chat
# 257                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 258                                 Bookmarking                         //trends.builtwith.com/widgets/bookmarking
# 259                              Social Sharing                      //trends.builtwith.com/widgets/social-sharing
# 260                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 261                         Schedule Management                 //trends.builtwith.com/widgets/schedule-management
# 262                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 263                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 264                              Image Provider                      //trends.builtwith.com/widgets/image-provider
# 265                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 266                                    Bookings                            //trends.builtwith.com/widgets/bookings
# 267                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 268                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 269                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 270                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 271                                       Login                               //trends.builtwith.com/widgets/login
# 272                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 273                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 274                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 275                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 276                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 277                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 278                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 279                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 280                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 281                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 282                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 283                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 284                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 285                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 286                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 287                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 288                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 289                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 290                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 291                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 292                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 293                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 294                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 295                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 296                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 297                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 298                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 299                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 300                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 301                                      Schema                            //trends.builtwith.com/framework/schema
# 302                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 303                                      Schema                            //trends.builtwith.com/framework/schema
# 304                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 305                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 306                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 307                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 308                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 309                                      Schema                            //trends.builtwith.com/framework/schema
# 310                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 311                                      Schema                            //trends.builtwith.com/framework/schema
# 312                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 313                                      Schema                            //trends.builtwith.com/framework/schema
# 314                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 315                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 316                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 317                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 318                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 319                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 320                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 321                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 322                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 323                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 324                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 325                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 326                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 327                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 328                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 329                                    Currency                            //trends.builtwith.com/payment/currency
# 330                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 331                                    Currency                            //trends.builtwith.com/payment/currency
# 332                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 333                                    Currency                            //trends.builtwith.com/payment/currency
# 334                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 335                       Live Stream / Webcast                 //trends.builtwith.com/media/live-stream---webcast
# 336                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 337                       Live Stream / Webcast                 //trends.builtwith.com/media/live-stream---webcast
# 338                       Online Video Platform                 //trends.builtwith.com/media/online-video-platform
# 339                       Social Video Platform                 //trends.builtwith.com/media/social-video-platform
# 340                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 341                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 342                           Digital Video Ads                     //trends.builtwith.com/media/digital-video-ads
# 343                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 344                                  Enterprise                              //trends.builtwith.com/cms/enterprise
# 345                                      Mobile                                  //trends.builtwith.com/cms/mobile
# 346                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 347                                  Enterprise                              //trends.builtwith.com/cms/enterprise
# 348                             Hosted Solution                         //trends.builtwith.com/cms/hosted-solution
# 349                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 350                            Ticketing System                        //trends.builtwith.com/cms/ticketing-system
# 351                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 352                                  Enterprise                              //trends.builtwith.com/cms/enterprise
# 353                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 354                                Landing Page                            //trends.builtwith.com/cms/landing-page
# 355                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 356                               Compatibility                    //trends.builtwith.com/javascript/compatibility
# 357                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 358                          JavaScript Library               //trends.builtwith.com/javascript/javascript-library
# 359                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 360                               jQuery Plugin                    //trends.builtwith.com/javascript/jquery-plugin
# 361                                          UI                               //trends.builtwith.com/javascript/ui
# 362                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 363                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 364                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 365                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 366                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 367                               Compatibility                    //trends.builtwith.com/javascript/compatibility
# 368                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 369                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 370                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 371                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 372                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 373                                   Framework                        //trends.builtwith.com/javascript/framework
# 374                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 375                          JavaScript Library               //trends.builtwith.com/javascript/javascript-library
# 376                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 377                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 378                                   Framework                        //trends.builtwith.com/javascript/framework
# 379                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 380                                   Animation                        //trends.builtwith.com/javascript/animation
# 381                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 382                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 383                               Compatibility                    //trends.builtwith.com/javascript/compatibility
# 384                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 385                          JavaScript Library               //trends.builtwith.com/javascript/javascript-library
# 386                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 387                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 388                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 389                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 390                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 391                          JavaScript Library               //trends.builtwith.com/javascript/javascript-library
# 392                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 393                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 394                          JavaScript Library               //trends.builtwith.com/javascript/javascript-library
# 395                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 396                                   Framework                        //trends.builtwith.com/javascript/framework
# 397                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 398                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 399                                  Ad Network                              //trends.builtwith.com/ads/ad-network
# 400                   Retargeting / Remarketing               //trends.builtwith.com/ads/retargeting---remarketing
# 401                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 402                   Retargeting / Remarketing               //trends.builtwith.com/ads/retargeting---remarketing
# 403                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 404                          Audience Targeting                      //trends.builtwith.com/ads/audience-targeting
# 405                               Multi-Channel                           //trends.builtwith.com/ads/multi-channel
# 406                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 407                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 408                        Demand-side Platform                    //trends.builtwith.com/ads/demand-side-platform
# 409                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 410                        Demand-side Platform                    //trends.builtwith.com/ads/demand-side-platform
# 411                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 412                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 413                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 414                   Retargeting / Remarketing               //trends.builtwith.com/ads/retargeting---remarketing
# 415                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# ...
# 729                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 730                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 731                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 732                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 733                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 734                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 735                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 736                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 737                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 738                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 739                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 740                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 741                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 742                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 743                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 744                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 745                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 746                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 747                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 748                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 749                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 750                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 751                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 752                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 753                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 754                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 755                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 756                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 757                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 758                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 759                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 760                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 761                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 762                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 763                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 764                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 765                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 766                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 767                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 768                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 769                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 770                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 771                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 772                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 773                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 774                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 775                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 776                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 777                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 778                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 779                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 780                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 781                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 782                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 783                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 784                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 785                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 786                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 787                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 788                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 789                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 790                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 791                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 792                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 793                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 794                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 795                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 796                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 797                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 798                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 799                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 800                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 801                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 802                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 803                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 804                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 805                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 806                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 807                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 808                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 809                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 810                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 811                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 812                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 813                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 814                         Upgrade to Advanced                                  //builtwith.com/checkout/advanced
# 815               View BuiltWith Top Site Rank.                                                            /top-1m
# 816                                      Add to
# 817                         Create Notification                                     /alerts/domain?ADD=juniper.net
# 818                                        JSON                      //api.builtwith.com/pass/json/v22/juniper.net
# 819                                         XML                       //api.builtwith.com/pass/xml/v22/juniper.net
# 820                                         CSV                       //api.builtwith.com/pass/csv/v22/juniper.net
# 821                        BuiltWith Domain API                                     //api.builtwith.com/domain-api
# 822                           Technology Lookup                                                    //builtwith.com
# 823                           Technology Trends                                             //trends.builtwith.com
# 824                     eCommerce Product Lists                                          //builtwith.com/ecommerce
# 825                               Keyword Lists                                      //builtwith.com/website-lists
# 826                                   Top Sites                                          //builtwith.com/top-sites
# 827                                   LeadsEye™                                           //leadseye.builtwith.com
# 828                             Plans & Pricing                                              //builtwith.com/plans
# 829                                     Sign Up                                             //builtwith.com/signup
# 830                                       Login                                              //builtwith.com/login
# 831                             Lead Generation                                    //builtwith.com/lead-generation
# 832                             Market Analysis                                    //builtwith.com/market-analysis
# 833                          Sales Intelligence                                 //builtwith.com/sales-intelligence
# 834                            Future Customers                                   //builtwith.com/future-customers
# 835                         Cyber Risk Auditing                                         //builtwith.com/cyber-risk
# 836                            Alternative Data                                   //builtwith.com/alternative-data
# 837                            Report Filtering                                   //builtwith.com/report-filtering
# 838                        Global Data Coverage                                      //builtwith.com/data-coverage
# 839                                All Features                                       //builtwith.com/all-features
# 840                                   Use Cases                                          //builtwith.com/use-cases
# 841                             Screencast Demo                                         //builtwith.com/screencast
# 842                              Knowledge Base                                                //kb.builtwith.com/
# 843                           Exportable Fields                                  //builtwith.com/exportable-fields
# 844                                  Screencast                                         //builtwith.com/screencast
# 845                                   Customers                                          //builtwith.com/customers
# 846                                         FAQ                                                //builtwith.com/faq
# 847                                        Blog                                              //blog.builtwith.com/
# 848                                    About Us                                              //builtwith.com/about
# 849                                  Contact Us                                            //builtwith.com/contact
# 850                                  Affiliates                                        //affiliates.builtwith.com/
# 851                                  API Access                                                //api.builtwith.com
# 852                                    Datasets                                           //builtwith.com/datasets
# 853                              BuiltWith + AI                            //builtwith.com/artificial-intelligence
# 854                          Browser Extensions                                            //builtwith.com/toolbar
# 855                            CRM Integrations                                   //builtwith.com/crm-integrations
# 856                                    Removals                                           //builtwith.com/removals
# 857                                Terms of Use                                              //builtwith.com/terms
# 858                              Privacy Policy                                            //builtwith.com/privacy
# 859                              Modern Slavery                                     //builtwith.com/modern-slavery
# 860                                                                                              //x.com/builtwith
# 861                                                                           //www.linkedin.com/company/builtwith
# 862                                                                                   //www.facebook.com/builtwith
# 863                                                                                        //tiktok.com/@builtwith
# 864                                                                                       //threads.net/@builtwith
# 865                                                                                       //vimeo.com/builtwithcom
# 866                                                                                         //github.com/builtwith
# 867                                                                                      //instagram.com/builtwith
